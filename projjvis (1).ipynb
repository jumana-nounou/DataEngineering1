# %%
from bokeh.io import output_file,show,output_notebook,push_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource,HoverTool,BoxSelectTool
from bokeh.layouts import row,column,gridplot
from bokeh.models.widgets import Tabs,Panel
output_notebook()
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
pip install data-patterns
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting data-patterns
#   Downloading data_patterns-0.1.24-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from data-patterns) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from data-patterns) (1.21.6)
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 21.2 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from data-patterns) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->data-patterns) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->data-patterns) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->data-patterns) (1.15.0)
# Installing collected packages: xlsxwriter, data-patterns
# Successfully installed data-patterns-0.1.24 xlsxwriter-3.0.3

# %%
import data_patterns

# %%
data = pd.read_csv("/content/Car_sale_ads.csv",engine="python", error_bad_lines=False)
pd.set_option('display.max_columns',None)
df = pd.DataFrame(data)
df
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Skipping line 1416: ',' expected after '"'
#          Index  Price Currency Condition Vehicle_brand Vehicle_model  \
# 0            0  86200      PLN       New        Abarth           595
# 1            1  43500      PLN      Used        Abarth         Other
# 2            2  44900      PLN      Used        Abarth           500
# 3            3  39900      PLN      Used        Abarth           500
# 4            4  97900      PLN       New        Abarth           595
# ...        ...    ...      ...       ...           ...           ...
# 193097  208299  39900      PLN      Used           Żuk         Other
# 193098  208300  10900      PLN      Used           Żuk         Other
# 193099  208301   6900      PLN      Used           Żuk         Other
# 193100  208302   5700      PLN      Used           Żuk         Other
# 193101  208303  11900      PLN      Used           Żuk         Other
#
#        Vehicle_version Vehicle_generation  Production_year  Mileage_km  \
# 0                  NaN                NaN             2021         1.0
# 1                  NaN                NaN             1974     59000.0
# 2                  NaN                NaN             2018     52000.0
# 3                  NaN                NaN             2012     29000.0
# 4                  NaN                NaN             2021       600.0
# ...                ...                ...              ...         ...
# 193097             NaN                NaN             2014     40000.0
# 193098             NaN                NaN             1970     63518.0
# 193099             NaN                NaN             1977     11880.0
# 193100             NaN                NaN             1986    100000.0
# 193101             NaN                NaN             1985     20056.0
#
#         Power_HP  Displacement_cm3 Fuel_type  CO2_emissions         Drive  \
# 0          145.0            1400.0  Gasoline            NaN  Front wheels
# 1           75.0            1100.0  Gasoline            NaN  Front wheels
# 2          180.0            1368.0  Gasoline            NaN           NaN
# 3          160.0            1368.0  Gasoline          139.0  Front wheels
# 4          165.0            1368.0  Gasoline            NaN           NaN
# ...          ...               ...       ...            ...           ...
# 193097     173.0            1301.0  Gasoline            NaN           NaN
# 193098      70.0            2120.0  Gasoline            NaN   Rear wheels
# 193099      60.0            2120.0  Gasoline            NaN           NaN
# 193100      36.0            2200.0  Gasoline            NaN           NaN
# 193101      70.0            2120.0  Gasoline            NaN           NaN
#
#        Transmission           Type  Doors_number  Colour Origin_country  \
# 0            Manual     small_cars           3.0    gray            NaN
# 1            Manual          coupe           2.0  silver            NaN
# 2         Automatic     small_cars           3.0  silver            NaN
# 3            Manual     small_cars           3.0    gray            NaN
# 4            Manual     small_cars           3.0    blue            NaN
# ...             ...            ...           ...     ...            ...
# 193097       Manual     small_cars           1.0   other            NaN
# 193098       Manual  station_wagon           4.0   other         Poland
# 193099       Manual            SUV           3.0     red            NaN
# 193100       Manual        minivan           2.0    blue            NaN
# 193101       Manual        minivan           3.0     red            NaN
#
#        First_owner First_registration_date Offer_publication_date  \
# 0              NaN                     NaN             04/05/2021
# 1              NaN                     NaN             03/05/2021
# 2              NaN                     NaN             03/05/2021
# 3              NaN                     NaN             30/04/2021
# 4              NaN                     NaN             30/04/2021
# ...            ...                     ...                    ...
# 193097         NaN                     NaN             30/04/2021
# 193098         NaN                     NaN             02/05/2021
# 193099         NaN              11/06/1977             28/04/2021
# 193100         NaN                     NaN             24/04/2021
# 193101         NaN                     NaN             04/05/2021
#
#                                            Offer_location  \
# 0       ul. Jubilerska 6 - 04-190 Warszawa, Mazowiecki...
# 1       kanonierska12 - 04-425 Warszawa, Rembertów (Po...
# 2                        Warszawa, Mazowieckie, Białołęka
# 3                                       Jaworzno, Śląskie
# 4       ul. Gorzysława 9 - 61-057 Poznań, Nowe Miasto ...
# ...                                                   ...
# 193097  ul. Huzarska 12 - 47-400 Racibórz, raciborski,...
# 193098                      Włocławek, Kujawsko-pomorskie
# 193099                   Złotów, złotowski, Wielkopolskie
# 193100                  Kraczkowa, łańcucki, Podkarpackie
# 193101  Szczecińska 40 - 75-137 Koszalin, Zachodniopom...
#
#                                                  Features
# 0                                                      []
# 1                                                      []
# 2       ['ABS', 'Electric front windows', 'Drivers air...
# 3       ['ABS', 'Electric front windows', 'Drivers air...
# 4       ['ABS', 'Electrically adjustable mirrors', 'Pa...
# ...                                                   ...
# 193097                                                 []
# 193098                                                 []
# 193099                                                 []
# 193100                                                 []
# 193101                                                 []
#
# [193102 rows x 25 columns]

# %% [markdown]
# # **I will be discussing and engineering data of 2 different research questions**
#
#
# 1.   ***Throughout the years, has a car's engine power and car's engine size (in cubic cintemeters) increased?***

# %% [markdown]
# *First, renaming features to be more descriptive*

# %%
data.rename(columns = {'Power_HP':'Engine_power_in_horsepower'}, inplace = True)
data.rename(columns = {'Displacement_cm3':'Engine_size_in_cc'}, inplace = True)

# %% [markdown]
# *I will discard all features except the ones mentioned in my research question*

# %%
data = data[['Production_year', 'Engine_power_in_horsepower','Engine_size_in_cc']]
data
# Out:
#         Production_year  Engine_power_in_horsepower  Engine_size_in_cc
# 0                  2021                       145.0             1400.0
# 1                  1974                        75.0             1100.0
# 2                  2018                       180.0             1368.0
# 3                  2012                       160.0             1368.0
# 4                  2021                       165.0             1368.0
# ...                 ...                         ...                ...
# 193097             2014                       173.0             1301.0
# 193098             1970                        70.0             2120.0
# 193099             1977                        60.0             2120.0
# 193100             1986                        36.0             2200.0
# 193101             1985                        70.0             2120.0
#
# [193102 rows x 3 columns]

# %% [markdown]
# *sort data by year of production ascendingly*

# %%
data = data.sort_values(by=['Production_year'])

# %% [markdown]
# *check for missing values in production year*

# %%
bool_series = pd.isnull(data["Production_year"])
data[bool_series]
# Out:
# Empty DataFrame
# Columns: [Production_year, Engine_power_in_horsepower, Engine_size_in_cc]
# Index: []

# %% [markdown]
# *check for missing values in engine's power (HP)*

# %%
bool_series = pd.isnull(data["Engine_power_in_horsepower"])
data[bool_series]
# Out:
#         Production_year  Engine_power_in_horsepower  Engine_size_in_cc
# 138703             1936                         NaN             3499.0
# 138774             1936                         NaN             1500.0
# 117727             1936                         NaN             1500.0
# 20145              1947                         NaN             5200.0
# 92480              1951                         NaN                NaN
# ...                 ...                         ...                ...
# 168966             2021                         NaN             1984.0
# 168963             2021                         NaN             1984.0
# 168970             2021                         NaN             1984.0
# 168897             2021                         NaN             1984.0
# 169927             2021                         NaN                NaN
#
# [599 rows x 3 columns]

# %% [markdown]
# *replace missing values with average of column*

# %%
data['Engine_power_in_horsepower'].fillna(value=df['Engine_power_in_horsepower'].mean(), inplace=True)
# Out:
#         Production_year  Engine_power_in_horsepower  Engine_size_in_cc
# 51485              1915                        16.0             2960.0
# 117275             1915                        16.0             2960.0
# 117726             1922                        50.0             2800.0
# 21768              1922                        50.0             2800.0
# 117604             1923                        25.0             1452.0
# ...                 ...                         ...                ...
# 155255             2017                       268.0             2000.0
# 155254             2017                       170.0             2500.0
# 182244             2017                        60.0              999.0
# 21763              2017                       450.0             6162.0
# 169855             2017                       102.0             1968.0
#
# [138704 rows x 3 columns]

# %% [markdown]
# *check for missing values in engine's size*

# %%
bool_series = pd.isnull(data["Engine_size_in_cc"])
data[bool_series]
# Out:
#         Production_year  Engine_power_in_horsepower  Engine_size_in_cc
# 92480              1951                        52.0                NaN
# 117765             1951                        52.0                NaN
# 67004              1954                         1.0                NaN
# 53214              1955                        77.0                NaN
# 117477             1965                       365.0                NaN
# ...                 ...                         ...                ...
# 145982             2021                       204.0                NaN
# 144301             2021                       204.0                NaN
# 144229             2021                       204.0                NaN
# 144885             2021                       204.0                NaN
# 24384              2021                       136.0                NaN
#
# [1636 rows x 3 columns]

# %% [markdown]
# *replace missing values with average of column*

# %%
data['Engine_size_in_cc'].fillna(value=df['Engine_size_in_cc'].mean(), inplace=True)
