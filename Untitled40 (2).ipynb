# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
data = pd.read_csv("/content/Car_sale_ads.csv")
pd.set_option('display.max_columns',None)
data
# Out:
#          Index  Price Currency Condition Vehicle_brand Vehicle_model  \
# 0            0  86200      PLN       New        Abarth           595
# 1            1  43500      PLN      Used        Abarth         Other
# 2            2  44900      PLN      Used        Abarth           500
# 3            3  39900      PLN      Used        Abarth           500
# 4            4  97900      PLN       New        Abarth           595
# ...        ...    ...      ...       ...           ...           ...
# 208299  208299  39900      PLN      Used           Żuk         Other
# 208300  208300  10900      PLN      Used           Żuk         Other
# 208301  208301   6900      PLN      Used           Żuk         Other
# 208302  208302   5700      PLN      Used           Żuk         Other
# 208303  208303  11900      PLN      Used           Żuk         Other
#
#        Vehicle_version Vehicle_generation  Production_year  Mileage_km  \
# ...

# %%
#we need to check the unique variable in currency
uniqueCurrency=data.Currency.unique()
#unique values in Vehicle_generation
uniqueGen=data.Vehicle_generation.unique()
#unique values in Vehicle_version
uniqueVersion=data.Vehicle_version.unique()
#unique values in Vehicle_brand
uniqueVehicle=data.Vehicle_brand.unique()
#checking the number of unique values of vehicle version
item=data['Vehicle_version'].value_counts()

#uniqueCurrency
#uniqueGen
#uniqueVersion
#uniqueVehicle
#item

# %%
percent_missing = data.isnull().sum() * 100 / len(data)
missing_value_df = pd.DataFrame({'column_name': data.columns, 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True)
missing_value_df
#i wanted to know which columns have many null values instead of looking at each column, so ill drop them
# Out:
#                                      column_name  percent_missing
# Index                                      Index         0.000000
# Offer_publication_date    Offer_publication_date         0.000000
# Colour                                    Colour         0.000000
# Type                                        Type         0.000000
# Offer_location                    Offer_location         0.000000
# Production_year                  Production_year         0.000000
# Fuel_type                              Fuel_type         0.000000
# Features                                Features         0.000000
# Vehicle_model                      Vehicle_model         0.000000
# Price                                      Price         0.000000
# Currency                                Currency         0.000000
# Condition                              Condition         0.000000
# Vehicle_brand                      Vehicle_brand         0.000000
# ...

# %%
# we will drop useless columns
df=pd.DataFrame(data)
df.drop(['First_owner','First_registration_date','Offer_location','Offer_publication_date','Currency','Index','Vehicle_version'], axis=1)


# if Im someone rich eh el hayefre2 ma3aya, condition new, vehicle version hahhahshd, vehicle generation , production year 2018 +,hp high,
# mileage less than 8k, omission min , drive mesh far2a, automatic ,
#Ecofriendly cars started in 1997

# If Im poor condition used , brand , model, version mesh hayfr2 as long as cheap,transmision wont matter HP,gas mesh hayefr2 type momken yefre2 
#, doors number yefre2


# what makes car ecofriendly? 
df
# Out:
#          Index  Price Currency Condition Vehicle_brand Vehicle_model  \
# 0            0  86200      PLN       New        Abarth           595
# 1            1  43500      PLN      Used        Abarth         Other
# 2            2  44900      PLN      Used        Abarth           500
# 3            3  39900      PLN      Used        Abarth           500
# 4            4  97900      PLN       New        Abarth           595
# ...        ...    ...      ...       ...           ...           ...
# 208299  208299  39900      PLN      Used           Żuk         Other
# 208300  208300  10900      PLN      Used           Żuk         Other
# 208301  208301   6900      PLN      Used           Żuk         Other
# 208302  208302   5700      PLN      Used           Żuk         Other
# 208303  208303  11900      PLN      Used           Żuk         Other
#
#        Vehicle_version Vehicle_generation  Production_year  Mileage_km  \
# ...

# %%
sns.pairplot(df)
sns.scatter(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e82aa7812627> in <module>
# ----> 1 sns.pairplot(df)
#       2 sns.scatter(df)
#
# NameError: name 'sns' is not defined
